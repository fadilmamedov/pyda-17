# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Задание 1
#
# Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# KEYWORDS = ['python', 'парсинг']
#
# Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>
#
# #### Дополнительная часть (необязательная)
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст_статьи>

# %%
keywords = ['diy', 'ceo', 'api']

request = requests.get('https://habr.com/ru/all/')
parser = BeautifulSoup(request.text, 'html.parser')

# %%
class Post:
  def __init__(self, post, use_full_content=False):
    self.post = post
    self.use_full_content = use_full_content
    
    self.date = self.get_date()
    self.title = self.get_title()
    self.hubs = self.get_hubs()
    self.short_content = self.get_short_content()
    
    if use_full_content:
      self.full_content = self.get_full_content()
    
  def get_date(self):
    return self.post.find('span', class_='post__time').text
    
  def get_title(self):
    link = self.post.find('a', class_='post__title_link')
    return (link.get('href'), link.text)
  
  def get_hubs(self):
    hubs = self.post.find_all('li', class_='inline-list__item_hub')
    return list(map(lambda hub: hub.find('a', class_='hub-link').text, hubs))
  
  def get_short_content(self):
    content = self.post.find('div', class_='post__text')
    return content.text
  
  def get_full_content(self):
    link = self.title[0]
    request = requests.get(link)
    post_parser = BeautifulSoup(request.text, 'html.parser')
    
    content = post_parser.find('div', id='post-content-body')
    return content.text;
  
  def is_keyword_in_title(self, keyword):
    link, text = self.title
    return keyword.lower() in text.lower()
  
  def is_keyword_in_short_content(self, keyword):
    return keyword.lower() in self.short_content.lower()
  
  def is_keyword_in_full_content(self, keyword):
    return keyword.lower() in self.full_content.lower()
  
  def is_keyword_in_hubs(self, keyword):
    for hub in self.hubs:
      if keyword.lower() in hub.lower():
        return True
      
    return False
  
  def contains_keyword(self, keyword):
    is_keyword_in_title = self.is_keyword_in_title(keyword)
    is_keyword_in_hubs = self.is_keyword_in_hubs(keyword)
    
    is_keyword_in_content = self.is_keyword_in_short_content(keyword)
    if self.use_full_content:
      is_keyword_in_content = self.is_keyword_in_full_content(keyword)
    
    return (
      is_keyword_in_title or
      is_keyword_in_hubs or
      is_keyword_in_content
    )
  
  def contains_keywords(self, keywords):
    for keyword in keywords:
      if self.contains_keyword(keyword):
        return True
      
    return False
  
  def to_dataframe(self):
    data = {
      'date': self.date,
      'link': self.title[0],
      'title': self.title[1],
    }
    
    if self.use_full_content:
      data['content'] = self.full_content
    
    return pd.DataFrame([data])

# %%
posts = []
page_posts = parser.find_all('article', class_='post post_preview')

for bs_post in page_posts:
  post = Post(bs_post, use_full_content=True)
  if post.contains_keywords(keywords):
    posts.append(post)
    
pd_posts = pd.DataFrame()
for post in posts:
  pd_posts = pd.concat([pd_posts, post.to_dataframe()])

pd_posts
# Out:
#             date                                               link  \
# 0  вчера в 23:50                   https://habr.com/ru/post/542214/
# 0  вчера в 18:21                   https://habr.com/ru/post/532154/
# 0  вчера в 18:13                   https://habr.com/ru/post/541874/
# 0  вчера в 16:55  https://habr.com/ru/company/netologyru/blog/54...
# 0  вчера в 16:44      https://habr.com/ru/company/otus/blog/542114/
# 0  вчера в 16:16  https://habr.com/ru/company/skillfactory/blog/...
#
#                                                title  \
# 0                DIY наушники. Как, а главное, зачем
# 0            Вторая главная обязанность CEO стартапа
# 0      ESP32-C3: первое знакомство. Заменим ESP8266?
# 0  Как начинающему нарративному или левел-дизайне...
# 0  Работа с адаптивным программируемым интерфейсо...
# 0  Mockito. Из чего он приготовлен и как его пода...
#
#                                              content
# 0  Хочу поделиться своим опытом прослушивания нау...
# 0  \n\nАли Рогани — работал в Pixar 9 лет (из них...
# 0  Новая игрушкаВ ноябре 2020 года Espressif анон...
# 0  Ранее мы расспросили опытных геймдизайнеров об...
# 0  Перевод статьи подготовлен в преддверии старта...
# 0  \r\nДумаю, многим довелось выпить какой-нибудь...

# %% [markdown]
# ### Задание 2
#
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. Список email-ов задаем переменной в начале кода:
# EMAIL = [xxx@x.ru, yyy@y.com]
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>
#
# Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %%
emails = ['fadil.mamedov@mail.ru', 'fadil.mamedov@gmail.com']

url = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'
data = {
  'emailAddresses': emails,
}
headers = {
  'Vaar-Header-App-Product': 'hackcheck-web-avast',
  'Vaar-Version': '0',
}

response = requests.post(url, json=data, headers=headers)
leaks = response.json()

# %%
pd_breaches = pd.DataFrame()

for email, value in leaks['summary'].items():
  breaches_ids = value['breaches']
  
  for breach_id in breaches_ids:
    breach = leaks['breaches'][str(breach_id)]
    
    data = {
      'email': email,
      'date': breach['publishDate'],
      'source': breach['site'],
      'description': breach['description']
    }
    
    pd_breaches = pd.concat([pd_breaches, pd.DataFrame([data])])
    
pd_breaches
# Out:
#                    email                  date             source  \
# 0  fadil.mamedov@mail.ru  2020-12-10T00:00:00Z     cubarecent.fun
# 0  fadil.mamedov@mail.ru  2017-08-30T00:00:00Z      sprashivai.ru
# 0  fadil.mamedov@mail.ru  2017-03-15T00:00:00Z       geekedin.net
# 0  fadil.mamedov@mail.ru  2017-06-14T00:00:00Z        nnm-club.me
# 0  fadil.mamedov@mail.ru  2017-04-10T00:00:00Z      sprashivai.ru
# 0  fadil.mamedov@mail.ru  2018-03-20T00:00:00Z   myfitnesspal.com
# 0  fadil.mamedov@mail.ru  2020-07-16T00:00:00Z  synergyregions.ru
# 0  fadil.mamedov@mail.ru  2017-01-16T00:00:00Z              fl.ru
#
#                                          description
# 0  In November 2020, a collection of over 23,000 ...
# 0  In January 2015, Sprashivai.ru's user database...
# 0  In August 2016, tech recruiting site GeekedIn....
# 0  In September 2013, Russian torrent tracker NNM...
# 0  In May 2015, Ask RU's user database was leaked...
# 0  In February 2018, MyFitnessPal's database was ...
# 0  At an unconfirmed date, the Russian university...
# 0  In February 2015, FL.ru's entire site database...

# %% [markdown]
# #### Дополнительная часть (необязательная)
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods , вам поможет метод wall.get
#
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>

# %%
url = 'https://api.vk.com/method/wall.get'

params = {
  'domain': 'netology',
  'count': 50,
  'v': '5.103',
  'access_token': 'a0f0885394f2ec6d9adbe9036b3a9eb1f8a194ea6d670a41d5c29d100ef0dcfbb773a9ee8d1a720254dd3'
}

res = requests.get(url, params)

# %%
vk_posts = res.json()['response']['items']

# %%
pd_vk_posts = pd.DataFrame()

for vk_post in vk_posts:
  data = {
    'date': pd.to_datetime(vk_post['date'], unit='s'),
    'content': vk_post['text'],
  }
  
  pd_vk_posts = pd.concat([pd_vk_posts, pd.DataFrame([data])])

# %%
pd_vk_posts
# Out:
#                  date                                            content
# 0 2021-02-10 14:13:00  Говорят, от даты рождения зависит характер и д...
# 0 2021-02-12 14:41:00  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 0 2021-02-12 07:59:00  В Data Science и программировании нужны люди с...
# 0 2021-02-11 14:59:00  Казалось бы, ничего сложного: сиди да задавай ...
# 0 2021-02-11 08:08:00  Погоня и перестрелка с полицией в GTA, загадоч...
# 0 2021-02-10 07:53:00  📆 15 февраля стартует бесплатный курс «Разрабо...
# 0 2021-02-09 14:57:00  Раз, два, три — эмоция замри 🤪 \n \nЭмоциональ...
# 0 2021-02-09 07:27:00  Кто стоит за всеми приложениями, играми и сайт...
# 0 2021-02-08 15:09:00  Сомнений больше нет: жизнь на удалёнке — есть ...
# 0 2021-02-08 07:38:00  Если интернет сравнить с экзотической страной,...
# 0 2021-02-07 13:07:00  *партнёрский пост*\n\n25-26 марта состоится ко...
# 0 2021-02-07 11:37:00  Можно положить кошелёк на подоконник в полнолу...
# 0 2021-02-06 12:07:00  *партнёрский пост* \n \nИздательство МИФ запус...
# 0 2021-02-06 08:07:00  Собрали подборку статей, в помощь начинающим S...
# 0 2021-02-05 14:27:00  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 0 2021-02-05 07:53:00  Где работать дизайнеру? 🤔 \nГрафический дизайн...
# 0 2021-02-04 14:53:00  Рабочие совещания могут быть настоящими пожира...
# 0 2021-02-04 08:13:00  Чтобы не повесить на двери табличку «закрыто»,...
# 0 2021-02-03 14:38:00  Иногда бывает сложно решиться на перемены в жи...
# 0 2021-02-03 07:37:00  🔥 8 февраля стартует бесплатный курс-путеводит...
# 0 2021-02-02 15:07:00  Конспекты экономят массу времени в будущем: не...
# 0 2021-02-02 07:53:00  Более половины работодателей ценят умение обща...
# 0 2021-02-01 15:22:00  Новые тренды в дизайне интерфейсов, необычные ...
# 0 2021-02-01 07:44:00  Мы верим, что в Data Science может работать ка...
# 0 2021-01-31 11:27:00  Умение быть приятным собеседником, которому до...
# 0 2021-01-30 12:41:00  «Ваш звонок очень важен для нас» 📞 \nДолгое ож...
# 0 2021-01-29 14:44:00  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 0 2021-01-29 07:44:00  Точно решили, кем хотите стать в диджитале, но...
# 0 2021-01-28 14:51:00  Как составить контент-план для социальных сете...
# 0 2021-01-28 07:57:00  Как научить робота готовить оливье, а нейросет...
# 0 2021-01-27 14:13:00  Сегодня задачка на внимательность: давайте узн...
# 0 2021-01-27 07:13:00  🚀 Запустили бесплатный курс «Основы Figma» \n ...
# 0 2021-01-26 14:48:00  Когда-то интернет состоял из текстов и простых...
# 0 2021-01-26 07:53:00  Киберпанк — фантастика или наше возможное буду...
# 0 2021-01-25 14:53:00  Анализ ЦА, знание основ психологии и базовых п...
# 0 2021-01-25 07:27:00  Карьера сегодня — не прямой и понятный путь из...
# 0 2021-01-24 11:15:00  Как влиять на людей с помощью слов и почему ум...
# 0 2021-01-23 11:22:00  Уехать и (не) вернуться: собрали статьи для те...
# 0 2021-01-22 15:10:00  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 0 2021-01-22 07:22:00  Учимся новому в удобное время: собрали бесплат...
# 0 2021-01-21 14:37:00  Бывает, что классные идеи приходят в самый нео...
# 0 2021-01-21 08:15:00  Зачастую мы подстраиваемся под профессии: трен...
# 0 2021-01-20 14:26:00  Грамотно распоряжаться своим временем — важный...
# 0 2021-01-20 07:26:00  📆 25 января стартует бесплатный курс «Как стат...
# 0 2021-01-19 14:48:00  Достаём двойные листочки 👩‍🏫 \n \nВ этом посте...
# 0 2021-01-19 07:36:00  Что произойдёт с данными после нас: цифровое б...
# 0 2021-01-18 15:15:00  С этого года работать удалённо стало проще. Та...
# 0 2021-01-18 07:29:00  🚀 21 января стартует «Неделя пробных занятий п...
# 0 2021-01-17 11:55:00  Что делать, если праздники прошли, а вы ни кап...
# 0 2021-01-16 11:29:00  Подкасты любят за возможность проводить время ...
